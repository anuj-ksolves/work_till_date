# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
def plot(X,m,b):
    regx = X.values
    regy = []
    for x in regx:
        y = m*x + b
        regy.append(y)
        
    plt.plot(regx,regy)
    plt.pause(1)

# %%
  
df = pd.read_csv("student_scores.csv")

X = df["Hours"]
y = df["Scores"]

plt.plot(X,y,'o')
plt.title("Gadient Descent")
plt.xlabel("Hours")
plt.ylabel("Student")
# Out:
# Text(0, 0.5, 'Student')

# %%
m = 0
c = 0

L = 0.0001
epochs = 1000  

n = float(len(X)) 
def grad_desc(x,y,m,c):
    for i in range(epochs): 
        Y_pred = m*X + c 
        D_m = (-2/n) * sum(X * (Y - Y_pred))
        D_c = (-2/n) * sum(Y - Y_pred)
        m = m - L * D_m
        c = c - L * D_c
    
    return(m,c)

# %%
for i in range(0,10):
    m,b = grad_desc(X,Y,m,b)
    print("coefficient values are:".format(m,b))
    plot(X,m,b)
  
plt.show()
# Out:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
# coefficient values are:
